# %%
import requests

response = requests.get("http://127.0.0.1:8000/get_recipe/healthybreakfast")
data = response.json()
print(data)
# Out:
# [{"product_id": {"20999": "113240600000", "8371": "113127700000", "26535": "113127800000", "3506": "110194100000", "27560": "101313000000", "38240": "109350200000", "3362": "271806302800", "28788": "271806302700", "31638": "271806302300", "2574": "271806302400"}, "sust_score": {"20999": 1.88, "8371": 1.88, "26535": 1.88, "3506": -0.79, "27560": -3.0, "38240": -3.0, "3362": -3.375, "28788": -3.375, "31638": -3.375, "2574": -3.375}}, {"product_id": {"14767": "104242200000", "33932": "104231600000", "18971": "521058400000", "24733": "131102400000", "2312": "104242500000", "13134": "104231400000", "23643": "104225100000", "1690": "111467500000", "6152": "104622100000", "16617": "104622000000"}, "sust_score": {"14767": -0.6061049020000002, "33932": -3.0, "18971": -3.0, "24733": -3.48, "2312": -3.6, "13134": -3.603, "23643": -3.603, "1690": -3.92, "6152": -3.92, "16617": -3.92}}, {"product_id": {"8817": "270813102300", "8816": "270813102300", "1232": "896601500000", "20543": "896400600000", "34125": "806464400000", "29603": "895220900000", "28881": "804692100000", "25836": "894924800000", "24675": "803584300000", "22739": "805425300000"}, "sust_score": {"8817": 1.6760000000000002, "8816": 0.6760000000000002, "1232": 0.0, "20543": 0.0, "34125": 0.0, "29603": 0.0, "28881": 0.0, "25836": 0.0, "24675": 0.0, "22739": 0.0}}, {"product_id": {"23326": "160550400000", "33185": "113376800000", "9585": "113806900000", "33702": "101025000000", "12300": "747272300001", "23784": "101000900000", "26213": "268107502100", "1944": "265608702300", "25660": "265200502400", "970": "265200202300"}, "sust_score": {"23326": -1.285, "33185": -1.8, "9585": -1.8, "33702": -3.0, "12300": -3.0, "23784": -3.0, "26213": -3.247, "1944": -3.4, "25660": -3.46, "970": -3.46}}, {"product_id": {"8679": "802974900000", "36438": "802977200000", "34774": "802974700000", "22033": "802977800000", "21097": "802974000000", "19009": "802974800000", "19728": "708211100000", "34245": "514878300000", "29270": "520569300000", "20006": "520568600000"}, "sust_score": {"8679": 0.0, "36438": 0.0, "34774": 0.0, "22033": 0.0, "21097": 0.0, "19009": 0.0, "19728": -3.0, "34245": -3.0, "29270": -3.0, "20006": -3.0}}, {"product_id": {"5008": "100115100000", "8622": "101558500000", "27056": "101558700000", "5832": "100100300000", "12227": "100110000000", "15458": "100115000000", "6309": "101558800000", "32913": "101559400000", "13135": "513235400000", "14419": "101357800000"}, "sust_score": {"5008": 1.0, "8622": 1.0, "27056": 1.0, "5832": 1.0, "12227": 1.0, "15458": 1.0, "6309": 1.0, "32913": 0.0, "13135": -3.0, "14419": -3.0}}, {"product_id": {"21894": "160916900000", "25549": "205017100300", "26628": "205002700000", "5485": "120904900000", "37901": "205061700900", "36749": "205017200200", "31558": "205018100100", "30105": "205068200300", "27818": "205071000800", "27730": "205018300800"}, "sust_score": {"21894": 0.0, "25549": -1.248, "26628": -1.249688646, "5485": -3.353, "37901": -4.248, "36749": -4.248, "31558": -4.248, "30105": -4.248, "27818": -4.248, "27730": -4.248}}, {"product_id": {"27862": "109106300000", "1640": "724408000000", "3193": "517825600000", "32004": "511728900000", "31591": "720503600000", "31399": "514898000000", "29888": "511729000000", "29124": "520573070000", "27925": "748916000000", "25243": "514878200000"}, "sust_score": {"27862": 1.0, "1640": -3.0, "3193": -3.0, "32004": -3.0, "31591": -3.0, "31399": -3.0, "29888": -3.0, "29124": -3.0, "27925": -3.0, "25243": -3.0}}, {"product_id": {"12572": "724253200000", "22683": "700166200001", "20755": "516239600000", "34245": "514878300000", "33061": "723983100009", "25243": "514878200000", "23432": "705652900000", "5130": "703755200000", "37141": "700159400006", "15502": "700166200002"}, "sust_score": {"12572": 0.0, "22683": -3.0, "20755": -3.0, "34245": -3.0, "33061": -3.0, "25243": -3.0, "23432": -3.0, "5130": -3.0, "37141": -3.0, "15502": -3.0}}, {"product_id": {"35692": "521094400000", "6542": "500591600000", "29246":  ...

# %%
#read product data and get name of 113127700000
import pandas as pd
df = pd.read_csv('Migros_case/products.csv')
print(df[df.id == "104242200000"]['name'].values[0])
print(df[df.id == "104231600000"]['name'].values[0])
print(df[df.id == "521058400000"]['name'].values[0])
# Out:
# Farmer Crunchy Honig
# Nestlé Nesquik Cereal
# Babybio Cerealien Kakao

# %%
df.abs
# Out:
# <bound method NDFrame.abs of                  id language                                      name  \
# 0      106512000000       en                    Bon Chef Café de Paris
# 1      747540400200       en        SUP LIVRE ENCHANTE LOULOUS BLEU_FR
# 2      703761100000       en      BLACK RACLETTE SPATULES 6 PIECES/SET
# 3      160621400000       en                     GLACETTA CARAMEL 400G
# 4      721461000021       en                   WASHI TAPE_GOLD VIERECK
# ...             ...      ...                                       ...
# 39051  104450300000       en                Demeter Maisgriess Bramata
# 39052  104192100000       en             Migros Bio ADR Älplermagronen
# 39053  130711700000       en          Anna's Best Saft Pink Grapefruit
# 39054  748954690000       en            DIE WERWÖLFE VON DÜSTERWALD_DE
# 39055  703765600000       en  RIPPLE EMBOSSED PORCELAIN CANISTER LARGE
#
#                                                    names  \
# 0               {'short_name': 'Bon Chef Café de Paris'}
# 1      {'short_name': 'SUP LIVRE ENCHANTE LOULOUS BLE...
# 2      {'short_name': 'BLACK RACLETTE SPATULES 6 PIEC...
# 3                {'short_name': 'GLACETTA CARAMEL 400G'}
# 4              {'short_name': 'WASHI TAPE_GOLD VIERECK'}
# ...                                                  ...
# 39051       {'short_name': 'Demeter Maisgriess Bramata'}
# 39052    {'short_name': 'Migros Bio ADR Älplermagronen'}
# 39053  {'short_name': "Anna's Best Saft Pink Grapefru...
# 39054   {'short_name': 'DIE WERWÖLFE VON DÜSTERWALD_DE'}
# 39055  {'short_name': 'RIPPLE EMBOSSED PORCELAIN CANI...
#
#                                                     slug  \
# 0                                 bon-chef-cafe-de-paris
# 1      sup-livre-enchante-loulous-bleu-fr-00-franzoes...
# 2                    black-raclette-spatules-6-piecesset
# 3                                  glacetta-caramel-400g
# 4                                washi-tape-gold-viereck
# ...                                                  ...
# 39051                         demeter-maisgriess-bramata
# 39052                     migros-bio-adr-aelplermagronen
# 39053                    annas-best-saft-pink-grapefruit
# 39054           die-werwoelfe-von-duesterwald-de-deutsch
# 39055           ripple-embossed-porcelain-canister-large
#
#                                                    slugs  type   boss_number  \
# 0      {'de': 'bon-chef-cafe-de-paris', 'fr': 'bon-ch...   0.0   11111081605
# 1      {'de': 'livre-enchante-loulous-fr-00-franzoesi...   2.0  130861301010
# 2      {'de': 'raclette-spachtel-703761100000', 'fr':...   0.0  150423086005
# 3      {'de': 'glacetta-caramel', 'fr': 'glacetta-car...   0.0   10518025105
# 4      {'de': 'washi-tape-stripes', 'fr': 'washi-tape...   2.0  150626930505
# ...                                                  ...   ...           ...
# 39051  {'de': 'demeter-maisgriess-bramata', 'fr': 'de...   0.0   11011262605
# 39052  {'de': 'migros-bio-adr-aelplermagronen', 'fr':...   0.0   11011277005
# 39053  {'de': 'annas-best-saft-pink-grapefruit', 'fr'...   0.0   20530480505
# 39054  {'de': 'werwoelfe-de-deutsch', 'fr': 'werwoelf...   2.0  130861450580
# 39055  {'de': 'porzellandose', 'fr': 'boite-porcelain...   0.0  150423071005
#
#       data_source                                             status  ...  \
# 0         SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 1         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 2         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 3         SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 4         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# ...           ...                                                ...  ...
# 39051     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39052     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39053     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39054     SAP-X12  {'id': 'currently-not-available', 'seasonal': ...  ...
# 39055     SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
#
#                                                   colors  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [{'label': 'schwarz', 'hex': '#000000', 'group...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39051                                                NaN
# 39052                                                NaN
# 39053                                                NaN
# 39054                                                NaN
# 39055                                                NaN
#
#                                    additional_categories care_labels  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 39051                                                NaN         NaN
# 39052                                                NaN         NaN
# 39053                                                NaN         NaN
# 39054  [[{'code': 'MEL_SHOP_CAT_SportOutdoor_Spielwar...         NaN
# 39055                                                NaN         NaN
#
#       logistical_information  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 39051                    NaN
# 39052                    NaN
# 39053                    NaN
# 39054                    NaN
# 39055                    NaN
#
#                                                 services short_description  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 39051                                                NaN               NaN
# 39052                                                NaN               NaN
# 39053                                                NaN               NaN
# 39054  {'logistics': [{'code': 'MEL_LOGISTIK_POSTPAKE...               NaN
# 39055                                                NaN               NaN
#
#       chemicals_declaration energy_efficiency main_variant_id videos
# 0                       NaN               NaN             NaN    NaN
# 1                       NaN               NaN             NaN    NaN
# 2                       NaN               NaN             NaN    NaN
# 3                       NaN               NaN             NaN    NaN
# 4                       NaN               NaN             NaN    NaN
# ...                     ...               ...             ...    ...
# 39051                   NaN               NaN             NaN    NaN
# 39052                   NaN               NaN             NaN    NaN
# 39053                   NaN               NaN             NaN    NaN
# 39054                   NaN               NaN             NaN    NaN
# 39055                   NaN               NaN             NaN    NaN
#
# [39056 rows x 62 columns]>

# %%
def try_parse(x):
    try:
        x= int(float(x))
        return str(x)
    except:
        return str(0)


df_fish = pd.read_csv('Migros_case/Fisch.csv',dtype={'Product_number': 'object'},sep=";")
df_fish.Product_number = df_fish.Product_number.apply(try_parse)

# %%
#merge fish dataframe on product_name with product csv (id)
product = pd.read_csv('Migros_case/products.csv')
product.id = product.id.astype(str)
df_fish = pd.read_csv('Migros_case/Fisch.csv',dtype={'Product_number': 'object'},sep=";")
df_fish.Product_number = df_fish.Product_number.apply(try_parse)
df_fish = df_fish.rename(columns={'Product_number': 'id',"Product_description":"fish_name"})
new_fish = product.merge(df_fish, on='id', how='left')
new_fish
# Out:
#                  id language                                      name  \
# 0      106512000000       en                    Bon Chef Café de Paris
# 1      747540400200       en        SUP LIVRE ENCHANTE LOULOUS BLEU_FR
# 2      703761100000       en      BLACK RACLETTE SPATULES 6 PIECES/SET
# 3      160621400000       en                     GLACETTA CARAMEL 400G
# 4      721461000021       en                   WASHI TAPE_GOLD VIERECK
# ...             ...      ...                                       ...
# 39076  104450300000       en                Demeter Maisgriess Bramata
# 39077  104192100000       en             Migros Bio ADR Älplermagronen
# 39078  130711700000       en          Anna's Best Saft Pink Grapefruit
# 39079  748954690000       en            DIE WERWÖLFE VON DÜSTERWALD_DE
# 39080  703765600000       en  RIPPLE EMBOSSED PORCELAIN CANISTER LARGE
#
#                                                    names  \
# 0               {'short_name': 'Bon Chef Café de Paris'}
# 1      {'short_name': 'SUP LIVRE ENCHANTE LOULOUS BLE...
# 2      {'short_name': 'BLACK RACLETTE SPATULES 6 PIEC...
# 3                {'short_name': 'GLACETTA CARAMEL 400G'}
# 4              {'short_name': 'WASHI TAPE_GOLD VIERECK'}
# ...                                                  ...
# 39076       {'short_name': 'Demeter Maisgriess Bramata'}
# 39077    {'short_name': 'Migros Bio ADR Älplermagronen'}
# 39078  {'short_name': "Anna's Best Saft Pink Grapefru...
# 39079   {'short_name': 'DIE WERWÖLFE VON DÜSTERWALD_DE'}
# 39080  {'short_name': 'RIPPLE EMBOSSED PORCELAIN CANI...
#
#                                                     slug  \
# 0                                 bon-chef-cafe-de-paris
# 1      sup-livre-enchante-loulous-bleu-fr-00-franzoes...
# 2                    black-raclette-spatules-6-piecesset
# 3                                  glacetta-caramel-400g
# 4                                washi-tape-gold-viereck
# ...                                                  ...
# 39076                         demeter-maisgriess-bramata
# 39077                     migros-bio-adr-aelplermagronen
# 39078                    annas-best-saft-pink-grapefruit
# 39079           die-werwoelfe-von-duesterwald-de-deutsch
# 39080           ripple-embossed-porcelain-canister-large
#
#                                                    slugs  type   boss_number  \
# 0      {'de': 'bon-chef-cafe-de-paris', 'fr': 'bon-ch...   0.0   11111081605
# 1      {'de': 'livre-enchante-loulous-fr-00-franzoesi...   2.0  130861301010
# 2      {'de': 'raclette-spachtel-703761100000', 'fr':...   0.0  150423086005
# 3      {'de': 'glacetta-caramel', 'fr': 'glacetta-car...   0.0   10518025105
# 4      {'de': 'washi-tape-stripes', 'fr': 'washi-tape...   2.0  150626930505
# ...                                                  ...   ...           ...
# 39076  {'de': 'demeter-maisgriess-bramata', 'fr': 'de...   0.0   11011262605
# 39077  {'de': 'migros-bio-adr-aelplermagronen', 'fr':...   0.0   11011277005
# 39078  {'de': 'annas-best-saft-pink-grapefruit', 'fr'...   0.0   20530480505
# 39079  {'de': 'werwoelfe-de-deutsch', 'fr': 'werwoelf...   2.0  130861450580
# 39080  {'de': 'porzellandose', 'fr': 'boite-porcelain...   0.0  150423071005
#
#       data_source                                             status  ...  \
# 0         SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 1         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 2         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 3         SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 4         SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# ...           ...                                                ...  ...
# 39076     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39077     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39078     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 39079     SAP-X12  {'id': 'currently-not-available', 'seasonal': ...  ...
# 39080     SAP-X12  {'id': 'available', 'seasonal': False, 'pim_st...  ...
#
#       care_labels  logistical_information  \
# 0             NaN                     NaN
# 1             NaN                     NaN
# 2             NaN                     NaN
# 3             NaN                     NaN
# 4             NaN                     NaN
# ...           ...                     ...
# 39076         NaN                     NaN
# 39077         NaN                     NaN
# 39078         NaN                     NaN
# 39079         NaN                     NaN
# 39080         NaN                     NaN
#
#                                                 services short_description  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 39076                                                NaN               NaN
# 39077                                                NaN               NaN
# 39078                                                NaN               NaN
# 39079  {'logistics': [{'code': 'MEL_LOGISTIK_POSTPAKE...               NaN
# 39080                                                NaN               NaN
#
#       chemicals_declaration energy_efficiency main_variant_id videos  \
# 0                       NaN               NaN             NaN    NaN
# 1                       NaN               NaN             NaN    NaN
# 2                       NaN               NaN             NaN    NaN
# 3                       NaN               NaN             NaN    NaN
# 4                       NaN               NaN             NaN    NaN
# ...                     ...               ...             ...    ...
# 39076                   NaN               NaN             NaN    NaN
# 39077                   NaN               NaN             NaN    NaN
# 39078                   NaN               NaN             NaN    NaN
# 39079                   NaN               NaN             NaN    NaN
# 39080                   NaN               NaN             NaN    NaN
#
#       fish_name M-Check Fisch
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
# ...         ...           ...
# 39076       NaN           NaN
# 39077       NaN           NaN
# 39078       NaN           NaN
# 39079       NaN           NaN
# 39080       NaN           NaN
#
# [39081 rows x 64 columns]

# %%
# search fish with name see
df_fish[df_fish.fish_name.str.contains("See")]
# Out:
#                id                  fish_name  M-Check Fisch
# 102  251108000000   SEL MSC Seeteufelbaeggli              4
# 113  251108000000      MSC Seeteufelfilet SB              4
# 185  250103000000        MSC Seezungenfilets              5
# 186  250103000000     MSC Seezungenfilet MAP              5
# 187  250103000000    MSC Seezungen kuefe MAP              5
# 188  250103000000        MSC Seezungen kuefe              5
# 189  250103000000       MSC Seezunge 300/400              5
# 191  251107000000  M-CLAS MSC Seelachsrucken              5
# 195  250206000000     MSC Seehecht Knusperli              5

# %%
#check if 251108000000 exist in product
product[product.name.str.startswith("MSC")]
# Out:
#                  id language                                name  \
# 36     251363201200       en               MSC Wildlachs Sockeye
# 274    154321000000       en                       MSC Thonpains
# 615    251363200000       en               MSC Wildlachs Sockeye
# 857    155023700000       en    MSC Heringfilet in Tomaten-Crème
# 1486   155993000000       en       MSC Filetti alici con cappero
# 2804   165032600000       en           MSC SEEHECHT O. KOPF 600G
# 3331   165033200000       en            MSC KLIESCHENFILETS 400G
# 3856   165054900000       en           MSC COCKTAIL SHRIMPS 300G
# 4314   165052700000       en                MSC JAKOBSNUESSE ROH
# 4613   250104936000       en               MSC Skrej Rückenfilet
# 5213   251108300000       en                   MSC Seeteufelfiet
# 6189   251105330300       en                     MSC Dorschfilet
# 6797   250104937000       en       MSC Skrej Kabeljaurückenfilet
# 7109   251363400000       en                MSC Alaska Wildlachs
# 7706   252100300000       en           MSC ATL.DORSCHFIL.PANIERT
# 7775   251440302001       en           MSC Surimi Snack Cocktail
# 9260   251104940000       en                  MSC Kabeljaurücken
# 9650   165033400000       en             MSC GOLDBUTTFILETS 400G
# 10564  252004000000       en           MSC SEEH.RUECKENFIL. 400G
# 10685  250104930500       en             MSC Kabeljaurückenfilet
# 11184  251440202000       en                  MSC Surimi Flocken
# 11991  251303200000       en  MSC Makrelenfilet geräucht pfeffer
# 12723  109064000000       en            MSC Delikat. Gelée Fisch
# 12758  251319100000       en      MSC Makrele ganz heissgeräucht
# 17573  251362240000       en                 MSC Wildlachs Royal
# 18908  250716430000       en                  MSC Hummerschwänze
# 18990  165011700000       en                  MSC Morue dessalée
# 19214  250108320000       en                  MSC Seeteufelfilet
# 19717  109061500000       en     MSC Delikat. in Gelee mit Lachs
# 19746  251363770000       en                  MSC Wildlachs Coho
# 20103  252013000000       en                    MSC SARDINEN 1KG
# 20218  251200616000       en   MSC Wildlachsfilet Zitrone - Dill
# 23441  250710030100       en                       MSC Crevetten
# 23599  165032400000       en            MSC ALASKA SEELACHS 900G
# 24052  251501230000       en           MSC Heringsfilets Bismark
# 24486  251514200000       en                  MSC Wildlachsrogen
# 29035  251505210000       en                   MSC Seehasenrogen
# 29278  251440002000       en                  MSC Surimistäbchen
# 29575  165041500000       en           MSC GOLDBUTTFIL. PAN.300G
# 32112  251326500000       en           MSC Heringsfilet geräucht
# 32434  252300300000       en                  MSC CREVETTEN 100G
# 32901  109091500000       en                     MSC Fischstücke
# 33096  155023900000       en      MSC Bücklingsfilets geräuchert
# 35421  165041300000       en            MSC DORSCH FISCHST. 300G
# 36926  165004700000       en           MSC ATL.KABELJAU RUECKENF
# 37380  165032300000       en            MSC WILDLACHSFILETS 250G
#
#                                                    names  \
# 36               {'short_name': 'MSC Wildlachs Sockeye'}
# 274                      {'short_name': 'MSC Thonpains'}
# 615              {'short_name': 'MSC Wildlachs Sockeye'}
# 857    {'short_name': 'MSC Heringfilet in Tomaten-Crè...
# 1486     {'short_name': 'MSC Filetti alici con cappero'}
# 2804         {'short_name': 'MSC SEEHECHT O. KOPF 600G'}
# 3331          {'short_name': 'MSC KLIESCHENFILETS 400G'}
# 3856         {'short_name': 'MSC COCKTAIL SHRIMPS 300G'}
# 4314              {'short_name': 'MSC JAKOBSNUESSE ROH'}
# 4613             {'short_name': 'MSC Skrej Rückenfilet'}
# 5213                 {'short_name': 'MSC Seeteufelfiet'}
# 6189                   {'short_name': 'MSC Dorschfilet'}
# 6797     {'short_name': 'MSC Skrej Kabeljaurückenfilet'}
# 7109              {'short_name': 'MSC Alaska Wildlachs'}
# 7706         {'short_name': 'MSC ATL.DORSCHFIL.PANIERT'}
# 7775         {'short_name': 'MSC Surimi Snack Cocktail'}
# 9260                {'short_name': 'MSC Kabeljaurücken'}
# 9650           {'short_name': 'MSC GOLDBUTTFILETS 400G'}
# 10564        {'short_name': 'MSC SEEH.RUECKENFIL. 400G'}
# 10685          {'short_name': 'MSC Kabeljaurückenfilet'}
# 11184               {'short_name': 'MSC Surimi Flocken'}
# 11991  {'short_name': 'MSC Makrelenfilet geräucht pfe...
# 12723         {'short_name': 'MSC Delikat. Gelée Fisch'}
# 12758   {'short_name': 'MSC Makrele ganz heissgeräucht'}
# 17573              {'short_name': 'MSC Wildlachs Royal'}
# 18908               {'short_name': 'MSC Hummerschwänze'}
# 18990               {'short_name': 'MSC Morue dessalée'}
# 19214               {'short_name': 'MSC Seeteufelfilet'}
# 19717  {'short_name': 'MSC Delikat. in Gelee mit Lachs'}
# 19746               {'short_name': 'MSC Wildlachs Coho'}
# 20103                 {'short_name': 'MSC SARDINEN 1KG'}
# 20218  {'short_name': 'MSC Wildlachsfilet Zitrone - D...
# 23441                    {'short_name': 'MSC Crevetten'}
# 23599         {'short_name': 'MSC ALASKA SEELACHS 900G'}
# 24052        {'short_name': 'MSC Heringsfilets Bismark'}
# 24486               {'short_name': 'MSC Wildlachsrogen'}
# 29035                {'short_name': 'MSC Seehasenrogen'}
# 29278               {'short_name': 'MSC Surimistäbchen'}
# 29575        {'short_name': 'MSC GOLDBUTTFIL. PAN.300G'}
# 32112        {'short_name': 'MSC Heringsfilet geräucht'}
# 32434               {'short_name': 'MSC CREVETTEN 100G'}
# 32901                  {'short_name': 'MSC Fischstücke'}
# 33096   {'short_name': 'MSC Bücklingsfilets geräuchert'}
# 35421         {'short_name': 'MSC DORSCH FISCHST. 300G'}
# 36926        {'short_name': 'MSC ATL.KABELJAU RUECKENF'}
# 37380         {'short_name': 'MSC WILDLACHSFILETS 250G'}
#
#                                       slug  \
# 36                   msc-wildlachs-sockeye
# 274                          msc-thonpains
# 615     msc-wildlachs-sockeye-251363200000
# 857       msc-heringfilet-in-tomaten-creme
# 1486         msc-filetti-alici-con-cappero
# 2804              msc-seehecht-o-kopf-600g
# 3331              msc-klieschenfilets-400g
# 3856             msc-cocktail-shrimps-300g
# 4314                  msc-jakobsnuesse-roh
# 4613                msc-skrej-rueckenfilet
# 5213                     msc-seeteufelfiet
# 6189          msc-dorschfilet-251105330300
# 6797        msc-skrej-kabeljaurueckenfilet
# 7109     msc-alaska-wildlachs-251363400000
# 7706               msc-atldorschfilpaniert
# 7775             msc-surimi-snack-cocktail
# 9260                   msc-kabeljauruecken
# 9650               msc-goldbuttfilets-400g
# 10564              msc-seehrueckenfil-400g
# 10685             msc-kabeljaurueckenfilet
# 11184                   msc-surimi-flocken
# 11991  msc-makrelenfilet-geraeucht-pfeffer
# 12723              msc-delikat-gelee-fisch
# 12758      msc-makrele-ganz-heissgeraeucht
# 17573                  msc-wildlachs-royal
# 18908                  msc-hummerschwaenze
# 18990                   msc-morue-dessalee
# 19214      msc-seeteufelfilet-250108320000
# 19717       msc-delikat-in-gelee-mit-lachs
# 19746      msc-wildlachs-coho-251363770000
# 20103                     msc-sardinen-1kg
# 20218      msc-wildlachsfilet-zitrone-dill
# 23441           msc-crevetten-250710030100
# 23599             msc-alaska-seelachs-900g
# 24052            msc-heringsfilets-bismark
# 24486                   msc-wildlachsrogen
# 29035                    msc-seehasenrogen
# 29278                  msc-surimistaebchen
# 29575              msc-goldbuttfil-pan300g
# 32112           msc-heringsfilet-geraeucht
# 32434                   msc-crevetten-100g
# 32901                     msc-fischstuecke
# 33096     msc-buecklingsfilets-geraeuchert
# 35421              msc-dorsch-fischst-300g
# 36926             msc-atlkabeljau-rueckenf
# 37380             msc-wildlachsfilets-250g
#
#                                                    slugs  type  boss_number  \
# 36     {'de': 'msc-wildlachs-sockeye', 'fr': 'msc-sau...   0.0  40414368010
# 274    {'de': 'msc-thonpains', 'fr': 'msc-pate-au-tho...   0.0  11111090110
# 615    {'de': 'msc-wildlachs-sockeye-251363200000', '...   0.0  40414361005
# 857    {'de': 'msc-heringfilet-in-tomaten-creme', 'fr...   0.0  11111093605
# 1486   {'de': 'msc-filetti-alici-con-cappero', 'fr': ...   0.0  11111092615
# 2804   {'de': 'pelican-msc-seehecht-ohne-kopf-1650326...   0.0  10510551105
# 3331   {'de': 'pelican-msc-atl-klieschenfilets', 'fr'...   0.0  10510550605
# 3856   {'de': 'pelican-msc-cocktail-crevetten-gekocht...   0.0  10510710605
# 4314   {'de': 'pelican-msc-jakobsnuesse-roh', 'fr': '...   0.0  10510711105
# 4613   {'de': 'msc-skrej-rueckenfilet', 'fr': 'msc-su...   0.0  40612351005
# 5213   {'de': 'msc-seeteufelfiet', 'fr': 'msc-filet-b...   0.0  40414362010
# 6189   {'de': 'msc-dorschfilet-251105330300', 'fr': '...   0.0  40414368020
# 6797   {'de': 'msc-skrej-kabeljaurueckenfilet', 'fr':...   0.0  40612351005
# 7109   {'de': 'msc-alaska-wildlachs', 'fr': 'msc-saum...   0.0  40414361005
# 7706   {'de': 'pelican-msc-atlantik-dorschfilets', 'f...   0.0  10510551605
# 7775   {'de': 'msc-surimi-snack-cocktail', 'fr': 'msc...   0.0  40414363505
# 9260   {'de': 'msc-kabeljauruecken', 'fr': 'msc-supre...   0.0  40414362510
# 9650   {'de': 'pelican-msc-goldbuttfilets-16503340000...   0.0  10510550605
# 10564  {'de': 'pelican-msc-seehecht-rueckenfilet', 'f...   0.0  10510550605
# 10685  {'de': 'msc-kabeljaurueckenfilet-250104930500'...   0.0  40612351005
# 11184  {'de': 'msc-surimi-flocken', 'fr': 'msc-rape-d...   0.0  40414363505
# 11991  {'de': 'msc-makrelenfilet-geraeucht-pfeffer', ...   0.0  40414361010
# 12723  {'de': 'msc-delikat-gelee-fisch', 'fr': 'msc-d...   0.0  11811632110
# 12758  {'de': 'msc-makrele-ganz-heissgeraeucht', 'fr'...   0.0  40414361010
# 17573  {'de': 'msc-wildlachs-royal', 'fr': 'msc-wildl...   0.0  40414361005
# 18908  {'de': 'msc-hummerschwaenze', 'fr': 'msc-queue...   0.0  40612352020
# 18990  {'de': 'msc-morue-dessalee', 'fr': 'msc-morue-...   0.0  10510551105
# 19214  {'de': 'msc-seeteufelfilet-250108320000', 'fr'...   0.0  40612351005
# 19717  {'de': 'msc-delikat-in-gelee-mit-lachs', 'fr':...   0.0  11811632110
# 19746  {'de': 'msc-wildlachs-coho', 'fr': 'msc-saumon...   0.0  40414361005
# 20103  {'de': 'pelican-msc-sardinen', 'fr': 'pelican-...   0.0  10510551105
# 20218  {'de': 'msc-wildlachsfilet-zitrone-dill', 'fr'...   0.0  40414362510
# 23441  {'de': 'msc-crevetten', 'fr': 'msc-crevettes',...   0.0  40612350505
# 23599  {'de': 'pelican-msc-alaska-seelachs', 'fr': 'p...   0.0  10510550605
# 24052  {'de': 'msc-heringsfilets-bismark', 'fr': 'msc...   0.0  40414364005
# 24486  {'de': 'msc-wildlachsrogen', 'fr': 'msc-oeufs-...   0.0  40414364010
# 29035  {'de': 'msc-seehasenrogen', 'fr': 'msc-oeufs-d...   0.0  40414364010
# 29278  {'de': 'msc-surimistaebchen', 'fr': 'msc-baton...   0.0  40414363505
# 29575  {'de': 'pelican-msc-goldbuttfilet-paniert', 'f...   0.0  10510551605
# 32112  {'de': 'msc-heringsfilet-geraeucht', 'fr': 'ms...   0.0  40414361010
# 32434  {'de': 'pelican-msc-crevetten', 'fr': 'pelican...   0.0  10510710605
# 32901  {'de': 'msc-fischstuecke', 'fr': 'msc-morceaux...   0.0  11811641615
# 33096  {'de': 'msc-buecklingsfilets-geraeuchert', 'fr...   0.0  11111093605
# 35421  {'de': 'pelican-msc-dorsch-fischstaebchen-1650...   0.0  10510551605
# 36926  {'de': 'pelican-msc-kabeljau-rueckenfilet', 'f...   0.0  10510550605
# 37380  {'de': 'pelican-msc-wildlachsfilets', 'fr': 'p...   0.0  10510550605
#
#       data_source                                             status  ...  \
# 36        SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 274       SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 615       SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 857       SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 1486      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 2804      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 3331      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 3856      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 4314      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 4613      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 5213      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 6189      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 6797      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 7109      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 7706      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 7775      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 9260      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 9650      SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 10564     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 10685     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 11184     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 11991     SAP-X11  {'id': 'currently-not-available', 'seasonal': ...  ...
# 12723     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 12758     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 17573     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 18908     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 18990     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 19214     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 19717     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 19746     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 20103     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 20218     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 23441     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 23599     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 24052     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 24486     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 29035     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 29278     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 29575     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 32112     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 32434     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 32901     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 33096     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 35421     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 36926     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
# 37380     SAP-X11  {'id': 'available', 'seasonal': False, 'pim_st...  ...
#
#       colors  additional_categories care_labels  \
# 36       NaN                    NaN         NaN
# 274      NaN                    NaN         NaN
# 615      NaN                    NaN         NaN
# 857      NaN                    NaN         NaN
# 1486     NaN                    NaN         NaN
# 2804     NaN                    NaN         NaN
# 3331     NaN                    NaN         NaN
# 3856     NaN                    NaN         NaN
# 4314     NaN                    NaN         NaN
# 4613     NaN                    NaN         NaN
# 5213     NaN                    NaN         NaN
# 6189     NaN                    NaN         NaN
# 6797     NaN                    NaN         NaN
# 7109     NaN                    NaN         NaN
# 7706     NaN                    NaN         NaN
# 7775     NaN                    NaN         NaN
# 9260     NaN                    NaN         NaN
# 9650     NaN                    NaN         NaN
# 10564    NaN                    NaN         NaN
# 10685    NaN                    NaN         NaN
# 11184    NaN                    NaN         NaN
# 11991    NaN                    NaN         NaN
# 12723    NaN                    NaN         NaN
# 12758    NaN                    NaN         NaN
# 17573    NaN                    NaN         NaN
# 18908    NaN                    NaN         NaN
# 18990    NaN                    NaN         NaN
# 19214    NaN                    NaN         NaN
# 19717    NaN                    NaN         NaN
# 19746    NaN                    NaN         NaN
# 20103    NaN                    NaN         NaN
# 20218    NaN                    NaN         NaN
# 23441    NaN                    NaN         NaN
# 23599    NaN                    NaN         NaN
# 24052    NaN                    NaN         NaN
# 24486    NaN                    NaN         NaN
# 29035    NaN                    NaN         NaN
# 29278    NaN                    NaN         NaN
# 29575    NaN                    NaN         NaN
# 32112    NaN                    NaN         NaN
# 32434    NaN                    NaN         NaN
# 32901    NaN                    NaN         NaN
# 33096    NaN                    NaN         NaN
# 35421    NaN                    NaN         NaN
# 36926    NaN                    NaN         NaN
# 37380    NaN                    NaN         NaN
#
#                                   logistical_information services  \
# 36                                                   NaN      NaN
# 274                                                  NaN      NaN
# 615                                                  NaN      NaN
# 857                                                  NaN      NaN
# 1486                                                 NaN      NaN
# 2804   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 3331   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 3856   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 4314   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 4613                                                 NaN      NaN
# 5213                                                 NaN      NaN
# 6189                                                 NaN      NaN
# 6797                                                 NaN      NaN
# 7109                                                 NaN      NaN
# 7706   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 7775                                                 NaN      NaN
# 9260                                                 NaN      NaN
# 9650   {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 10564  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 10685                                                NaN      NaN
# 11184                                                NaN      NaN
# 11991                                                NaN      NaN
# 12723                                                NaN      NaN
# 12758                                                NaN      NaN
# 17573                                                NaN      NaN
# 18908                                                NaN      NaN
# 18990  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 19214                                                NaN      NaN
# 19717                                                NaN      NaN
# 19746                                                NaN      NaN
# 20103  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 20218                                                NaN      NaN
# 23441                                                NaN      NaN
# 23599  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 24052                                                NaN      NaN
# 24486                                                NaN      NaN
# 29035                                                NaN      NaN
# 29278                                                NaN      NaN
# 29575  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 32112                                                NaN      NaN
# 32434  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 32901                                                NaN      NaN
# 33096                                                NaN      NaN
# 35421  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 36926  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
# 37380  {'frozen': True, 'frozen_pictogram': {'origina...      NaN
#
#       short_description chemicals_declaration energy_efficiency  \
# 36                  NaN                   NaN               NaN
# 274                 NaN                   NaN               NaN
# 615                 NaN                   NaN               NaN
# 857                 NaN                   NaN               NaN
# 1486                NaN                   NaN               NaN
# 2804                NaN                   NaN               NaN
# 3331                NaN                   NaN               NaN
# 3856                NaN                   NaN               NaN
# 4314                NaN                   NaN               NaN
# 4613                NaN                   NaN               NaN
# 5213                NaN                   NaN               NaN
# 6189                NaN                   NaN               NaN
# 6797                NaN                   NaN               NaN
# 7109                NaN                   NaN               NaN
# 7706                NaN                   NaN               NaN
# 7775                NaN                   NaN               NaN
# 9260                NaN                   NaN               NaN
# 9650                NaN                   NaN               NaN
# 10564               NaN                   NaN               NaN
# 10685               NaN                   NaN               NaN
# 11184               NaN                   NaN               NaN
# 11991               NaN                   NaN               NaN
# 12723               NaN                   NaN               NaN
# 12758               NaN                   NaN               NaN
# 17573               NaN                   NaN               NaN
# 18908               NaN                   NaN               NaN
# 18990               NaN                   NaN               NaN
# 19214               NaN                   NaN               NaN
# 19717               NaN                   NaN               NaN
# 19746               NaN                   NaN               NaN
# 20103               NaN                   NaN               NaN
# 20218               NaN                   NaN               NaN
# 23441               NaN                   NaN               NaN
# 23599               NaN                   NaN               NaN
# 24052               NaN                   NaN               NaN
# 24486               NaN                   NaN               NaN
# 29035               NaN                   NaN               NaN
# 29278               NaN                   NaN               NaN
# 29575               NaN                   NaN               NaN
# 32112               NaN                   NaN               NaN
# 32434               NaN                   NaN               NaN
# 32901               NaN                   NaN               NaN
# 33096               NaN                   NaN               NaN
# 35421               NaN                   NaN               NaN
# 36926               NaN                   NaN               NaN
# 37380               NaN                   NaN               NaN
#
#       main_variant_id videos
# 36                NaN    NaN
# 274               NaN    NaN
# 615               NaN    NaN
# 857               NaN    NaN
# 1486              NaN    NaN
# 2804              NaN    NaN
# 3331              NaN    NaN
# 3856              NaN    NaN
# 4314              NaN    NaN
# 4613              NaN    NaN
# 5213              NaN    NaN
# 6189              NaN    NaN
# 6797              NaN    NaN
# 7109              NaN    NaN
# 7706              NaN    NaN
# 7775              NaN    NaN
# 9260              NaN    NaN
# 9650              NaN    NaN
# 10564             NaN    NaN
# 10685             NaN    NaN
# 11184             NaN    NaN
# 11991             NaN    NaN
# 12723             NaN    NaN
# 12758             NaN    NaN
# 17573             NaN    NaN
# 18908             NaN    NaN
# 18990             NaN    NaN
# 19214             NaN    NaN
# 19717             NaN    NaN
# 19746             NaN    NaN
# 20103             NaN    NaN
# 20218             NaN    NaN
# 23441             NaN    NaN
# 23599             NaN    NaN
# 24052             NaN    NaN
# 24486             NaN    NaN
# 29035             NaN    NaN
# 29278             NaN    NaN
# 29575             NaN    NaN
# 32112             NaN    NaN
# 32434             NaN    NaN
# 32901             NaN    NaN
# 33096             NaN    NaN
# 35421             NaN    NaN
# 36926             NaN    NaN
# 37380             NaN    NaN
#
# [46 rows x 62 columns]

# %%
# read product csv 
product = pd.read_csv('Migros_case/sust_score.csv')
# order by bigger sust_score
product = product.sort_values(by=['sust_score'], ascending=False)
# get top 10
product.head(10).reset_index()
# Out:
#    index    product_id  sust_score  popularity  \
# 0  37812  105232000000    3.661000    0.000285
# 1  12975  104485300000    3.109000    0.000058
# 2  20654  113280000000    2.880000    0.000019
# 3  12357  114090900000    2.880000    0.000079
# 4  18990  114040000000    2.880000    0.000264
# 5  20558  130134300000    2.590000    0.000000
# 6  22306  131119500000    2.520000    0.000019
# 7   8923  104247500000    2.393895    0.000003
# 8  26082  104243500000    2.390000    0.000000
# 9  34613  130812000000    2.377000    0.000029
#
#                                    name
# 0                      Sun Queen Feigen
# 1       Berner Rösti mit Süsskartoffeln
# 2                       Gugelhopf Kakao
# 3                  Zigerkrapfen 2 Stück
# 4                        Mini Schenkeli
# 5        Migros Bio Fiori Kürbis Salbei
# 6  Anna's Best Bio Kürbis gewürfelt roh
# 7              Farmer Soft Choc Marroni
# 8         Farmer Soft Maple Syrup Pecan
# 9      Anna's Best Birchermüesli Winter

# %%
# get index 22306,37812,34613, i want their product_id
healthy_breakfast_ids = product.iloc[[0,7	,9]].product_id.tolist()
healthy_breakfast_scores = product.iloc[[0,7	,9]].sust_score.tolist()

#take healthy_breakfast_ids from product csv
product = pd.read_csv('Migros_case/products.csv')

# %%
import ast 
selected_product = product[product.id.isin(healthy_breakfast_ids)]
selected_product["image_url"] = selected_product["image"].apply(lambda x: ast.literal_eval(x)["original"])
selected_product["sust_score"] = healthy_breakfast_scores
selected_product[['id','name','sust_score','image_url']]
# Out:
# /var/folders/7g/2ds3y3yd6319x1125r61pg1c0000gn/T/ipykernel_18034/2188849852.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_product["image_url"] = selected_product["image"].apply(lambda x: ast.literal_eval(x)["original"])
# /var/folders/7g/2ds3y3yd6319x1125r61pg1c0000gn/T/ipykernel_18034/2188849852.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_product["sust_score"] = healthy_breakfast_scores
#                  id                              name  sust_score  \
# 8922   104247500000          Farmer Soft Choc Marroni    3.661000
# 34611  130812000000  Anna's Best Birchermüesli Winter    2.393895
# 37810  105232000000                  Sun Queen Feigen    2.377000
#
#                                                image_url
# 8922   https://image.migros.ch/original/12315d16faaf8...
# 34611  https://image.migros.ch/original/25ec4c54bf773...
# 37810  https://image.migros.ch/original/bc11a74b7e7c8...
